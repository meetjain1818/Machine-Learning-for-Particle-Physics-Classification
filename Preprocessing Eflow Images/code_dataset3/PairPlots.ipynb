# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %%
signal = pd.read_csv('/teamspace/studios/this_studio/Preprocessing Eflow Images/data/dataset3/sig_btagged2jets.txt', sep = '\t')
background = pd.read_csv('/teamspace/studios/this_studio/Preprocessing Eflow Images/data/dataset3/bg_btagged2jets.txt', sep = '\t')

# %%
def get_required_columns(dataframe, columns):
    df = dataframe[columns]
    return df

# %%
jet_columns = ['jet1_Eta', 'jet1_Phi', 'jet2_Eta', 'jet2_Phi', 'isophoton_Eta', 'isophoton_Phi']
b_columns = ['highb_Eta', 'highb_Phi', 'lowb_Eta', 'lowb_Phi', 'genphoton_Eta', 'genphoton_Phi']

# %%
jet_signal = get_required_columns(signal, jet_columns)
b_signal = get_required_columns(signal, b_columns)

jet_background = get_required_columns(background, jet_columns)
b_background = get_required_columns(background, b_columns)

# %%
len(background)
len(signal)
# Out:
# 886

# %% [markdown]
# # For jet1, jet2 and isophoton

# %% [markdown]
# ## Eta

# %%
sns.pairplot(jet_signal[['jet1_Eta', 'jet2_Eta', 'isophoton_Eta']])
plt.suptitle('SIGNAL: jet1, jet2 and isophoton Eta', fontsize = 20)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(jet_background[['jet1_Eta', 'jet2_Eta', 'isophoton_Eta']])
plt.suptitle('BACKGROUND: jet1, jet2 and isophoton Eta', fontsize = 15)
plt.tight_layout()
plt.show()

# %%
sns.heatmap(jet_signal[['jet1_Eta', 'jet2_Eta', 'isophoton_Eta']].corr(), cmap = 'mako', annot = True)
plt.title('SIGNAL: Correlations for jet1, jet2 and isophoton Eta', fontsize = 15)
plt.show()

# %%
sns.heatmap(jet_background[['jet1_Eta', 'jet2_Eta', 'isophoton_Eta']].corr(), cmap = 'mako', annot = True)
plt.title('BACKGROUND: Correlations for jet1, jet2 and isophoton Eta', fontsize = 15)
plt.show()

# %% [markdown]
# ## Phi

# %%
sns.pairplot(jet_signal[['jet1_Phi', 'jet2_Phi', 'isophoton_Phi']])
plt.suptitle('SIGNAL: jet1, jet2 and isophoton Phi', fontsize = 15)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(jet_background[['jet1_Phi', 'jet2_Phi', 'isophoton_Phi']])
plt.suptitle('BACKGROUND: jet1, jet2 and isophoton Phi', fontsize = 15)
plt.tight_layout()
plt.show()

# %%
sns.heatmap(jet_signal[['jet1_Phi', 'jet2_Phi', 'isophoton_Phi']].corr(), cmap = 'mako', annot = True)
plt.title('SIGNAL: Correlation Matrix for jet1, jet2 and isophoton Phi', fontsize = 15)
plt.show()

# %%
sns.heatmap(jet_background[['jet1_Phi', 'jet2_Phi', 'isophoton_Phi']].corr(), cmap = 'mako', annot = True)
plt.title('BACKGROUND: Correlation Matrix for jet1, jet2 and isophoton Phi', fontsize = 15)
plt.show()

# %% [markdown]
# # For the highb, lowb and genphoton

# %% [markdown]
# ## Eta

# %%
sns.pairplot(b_signal[['highb_Eta', 'lowb_Eta', 'genphoton_Eta']])
plt.suptitle('SIGNAL: highb, lowb and genphoton Eta', fontsize = 20)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(b_background[['highb_Eta', 'lowb_Eta', 'genphoton_Eta']])
plt.suptitle('BACKGROUND: highb, lowb and genphoton Eta', fontsize = 15)
plt.tight_layout()
plt.show()

# %%
sns.heatmap(b_signal[['highb_Eta', 'lowb_Eta', 'genphoton_Eta']].corr(), cmap = 'mako', annot = True)
plt.title('SIGNAL: Correlations for highb, lowb and genphoton Eta', fontsize = 15)
plt.show()

# %%
sns.heatmap(b_background[['highb_Eta', 'lowb_Eta', 'genphoton_Eta']].corr(), cmap = 'mako', annot = True)
plt.title('BACKGROUND: Correlations for highb, lowb and genphoton Eta', fontsize = 15)
plt.show()

# %% [markdown]
# ## Phi

# %%
sns.pairplot(b_signal[['highb_Phi', 'lowb_Phi', 'genphoton_Phi']])
plt.suptitle('SIGNAL: highb, lowb and genphoton Phi', fontsize = 20)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(b_background[['highb_Phi', 'lowb_Phi', 'genphoton_Phi']])
plt.suptitle('BACKGROUND: highb, lowb and genphoton Phi', fontsize = 15)
plt.tight_layout()
plt.savefig('1.png')
plt.show()

# %%
sns.heatmap(b_signal[['highb_Phi', 'lowb_Phi', 'genphoton_Phi']].corr(), cmap = 'mako', annot = True)
plt.title('SIGNAL: Correlations for highb, lowb and genphoton Phi', fontsize = 15)
plt.show()

# %%
sns.heatmap(b_background[['highb_Phi', 'lowb_Phi', 'genphoton_Phi']].corr(), cmap = 'mako', annot = True)
plt.title('BACKGROUND: Correlations for highb, lowb and genphoton Phi', fontsize = 15)
plt.show()

# %% [markdown]
# ### PROBABILITY ESTIMATION

# %%
signal_gen = jet_signal[['jet1_Phi','isophoton_Phi']] 
background_gen = jet_background[['jet1_Phi','isophoton_Phi']]

# %%
plt.figure(figsize = (6,6)) 
plt.scatter(signal_gen['jet1_Phi'], signal_gen['isophoton_Phi'], color = 'blue', alpha = 0.5, label = 'Signal') 
plt.scatter(background_gen['jet1_Phi'], background_gen['isophoton_Phi'], color = 'green', alpha = 0.5, label = 'Background') 
plt.xlabel('highb_Phi')
plt.ylabel('genphoton_Phi')
plt.title('Signal vs background: highb_Phi and genphoton_Phi') 
plt.legend()
plt.show()

# %% [markdown]
# # Probability Distibutions and KL Divergence

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import entropy
from sklearn.neighbors import KernelDensity

def analyze_phi_distributions(signal_phi1, signal_phi2, background_phi1, background_phi2, 
                            bins=50, bandwidth=0.1):
    """
    Analyze and visualize phi distributions for signal and background events.
    
    Parameters:
    -----------
    signal_phi1, signal_phi2: array-like
        Phi values for the two objects in signal events
    background_phi1, background_phi2: array-like
        Phi values for the two objects in background events
    bins: int
        Number of bins for histogram
    bandwidth: float
        Bandwidth parameter for kernel density estimation
    """
    # Create figure with multiple subplots
    fig = plt.figure(figsize=(15, 10))
    
    # 2D scatter plot
    ax1 = plt.subplot(221)
    ax1.scatter(signal_phi1, signal_phi2, alpha=0.5, label='Signal', s=10)
    ax1.scatter(background_phi1, background_phi2, alpha=0.5, label='Background', s=10)
    ax1.set_xlabel('Φ₁')
    ax1.set_ylabel('Φ₂')
    ax1.set_title('2D Distribution of Φ Values')
    ax1.legend()
    
    # Compute KDE for both distributions
    X_sig = np.vstack([signal_phi1, signal_phi2]).T
    X_bkg = np.vstack([background_phi1, background_phi2]).T
    
    # Fit KDE
    kde_sig = KernelDensity(bandwidth=bandwidth).fit(X_sig)
    kde_bkg = KernelDensity(bandwidth=bandwidth).fit(X_bkg)
    
    # Create grid for density estimation
    x_grid = np.linspace(min(min(signal_phi1), min(background_phi1)),
                        max(max(signal_phi1), max(background_phi1)), 100)
    y_grid = np.linspace(min(min(signal_phi2), min(background_phi2)),
                        max(max(signal_phi2), max(background_phi2)), 100)
    X_grid, Y_grid = np.meshgrid(x_grid, y_grid)
    xy_grid = np.vstack([X_grid.ravel(), Y_grid.ravel()]).T
    
    # Compute log densities
    Z_sig = np.exp(kde_sig.score_samples(xy_grid)).reshape(X_grid.shape)
    Z_bkg = np.exp(kde_bkg.score_samples(xy_grid)).reshape(X_grid.shape)
    
    # Plot signal KDE
    ax2 = plt.subplot(222)
    c2 = ax2.contourf(X_grid, Y_grid, Z_sig, levels=20, cmap='viridis')
    plt.colorbar(c2, ax=ax2)
    ax2.set_title('Signal Density Estimation')
    ax2.set_xlabel('Φ₁')
    ax2.set_ylabel('Φ₂')
    
    # Plot background KDE
    ax3 = plt.subplot(223)
    c3 = ax3.contourf(X_grid, Y_grid, Z_bkg, levels=20, cmap='viridis')
    plt.colorbar(c3, ax=ax3)
    ax3.set_title('Background Density Estimation')
    ax3.set_xlabel('Φ₁')
    ax3.set_ylabel('Φ₂')
    
    # Calculate KL divergence
    # Normalize distributions
    Z_sig_norm = Z_sig / Z_sig.sum()
    Z_bkg_norm = Z_bkg / Z_bkg.sum()
    
    # Add small constant to avoid division by zero
    epsilon = 1e-10
    Z_sig_norm = Z_sig_norm + epsilon
    Z_bkg_norm = Z_bkg_norm + epsilon
    
    # Calculate KL divergence in both directions
    kl_div_sig_bkg = entropy(Z_sig_norm.flatten(), Z_bkg_norm.flatten())
    kl_div_bkg_sig = entropy(Z_bkg_norm.flatten(), Z_sig_norm.flatten())
    
    # Plot difference
    ax4 = plt.subplot(224)
    diff = Z_sig_norm - Z_bkg_norm
    c4 = ax4.contourf(X_grid, Y_grid, diff, levels=20, cmap='RdBu')
    plt.colorbar(c4, ax=ax4)
    ax4.set_title('Density Difference (Signal - Background)')
    ax4.set_xlabel('Φ₁')
    ax4.set_ylabel('Φ₂')
    
    plt.tight_layout()
    
    return {
        'kl_divergence_sig_bkg': kl_div_sig_bkg,
        'kl_divergence_bkg_sig': kl_div_bkg_sig,
        'signal_kde': kde_sig,
        'background_kde': kde_bkg
    }

# %%
results = analyze_phi_distributions(signal_gen.loc[:,'highb_Phi'], signal_gen.loc[:,'genphoton_Phi'], background_gen.loc[:,'highb_Phi'], background_gen.loc[:,'genphoton_Phi'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'highb_Phi'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ...

# %%
print(f"KL divergence (signal → background): {results['kl_divergence_sig_bkg']:.4f}")
print(f"KL divergence (background → signal): {results['kl_divergence_bkg_sig']:.4f}")
