# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np
import cv2
import zipfile
import shutil
import warnings
from typing import List
from typing import Tuple
from PIL import Image
import pandas as pd
from sklearn.model_selection import train_test_split

warnings.filterwarnings('ignore')
plt.style.use('ggplot')

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Input, LeakyReLU

from tensorflow.keras.callbacks import ModelCheckpoint

from tensorflow.keras.models import load_model

seed = 1235
tf.random.set_seed(seed)

# Avoid OOM errors by setting GPU Memory Consumption Growth when using GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
def plot_metrics(model, *, names=['loss', 'val_loss', 'accuracy', 'val_accuracy', 'auc', 'val_auc']):
    """
    Plot training and validation metrics from a model's training history.
    
    This function creates a figure with three subplots showing the progression of different
    metrics (loss, accuracy, and AUC) over training epochs. Each subplot displays both the
    training and validation metrics for easy comparison.
    
    Parameters
    ----------
    model : tf.keras.callbacks.History
        The history object returned by model.fit() containing the training metrics.
        Should have the specified metrics in its history dictionary.
    names : list of str, optional
        List of metric names to plot. Should contain 6 strings in the order:
        [training_loss, val_loss, training_acc, val_acc, training_auc, val_auc].
        Default is ['loss', 'val_loss', 'accuracy', 'val_accuracy', 'auc', 'val_auc'].
        
    Returns
    -------
    None
        The function displays the plot but doesn't return any values.
        
    Raises
    ------
    KeyError
        If any of the specified metric names are not found in model.history.
    ValueError
        If the names list doesn't contain exactly 6 metrics.
        
    Examples
    --------
    >>> history = model.fit(x_train, y_train, validation_data=(x_val, y_val))
    >>> plot_metrics(history)
    
    >>> # With custom metric names
    >>> plot_metrics(history, names=['loss', 'val_loss', 'binary_accuracy', 
                                   'val_binary_accuracy', 'auc', 'val_auc'])
    
    Notes
    -----
    - The function creates a 1x3 grid of subplots with the following arrangement:
        1. Loss metrics (left)
        2. Accuracy metrics (middle)
        3. AUC metrics (right)
    - Training metrics are plotted in teal
    - Validation metrics are plotted in orange
    - The figure is created with a size of 10x5 inches and 300 DPI
    """
    # Validate input
    if len(names) != 6:
        raise ValueError("Expected 6 metric names, got {len(names)}")
    
    # Pre-fetch all data at once to avoid multiple dictionary lookups
    try:
        metrics_data = {name: model.history[name] for name in names}
    except KeyError as e:
        raise KeyError(f"Metric {e} not found in model history. Available metrics: {list(model.history.keys())}")
    
    # Create figure and subplots
    fig, axes = plt.subplots(1, 3, figsize=(10, 5), dpi=300)
    plt.suptitle('Performance Metrics', fontsize=15)
    
    # Define plot configurations
    plot_configs = [
        {'idx': 0, 'metrics': names[0:2], 'title': 'Loss', 'colors': ['teal', 'orange']},
        {'idx': 1, 'metrics': names[2:4], 'title': 'Accuracy', 'colors': ['teal', 'orange']},
        {'idx': 2, 'metrics': names[4:6], 'title': 'AUC', 'colors': ['teal', 'orange']}
    ]
    
    # Create plots using a loop
    for config in plot_configs:
        ax = axes[config['idx']]
        for metric, color in zip(config['metrics'], config['colors']):
            ax.plot(metrics_data[metric], color=color, label=metric)
        ax.set_title(config['title'], fontsize=10)
        ax.set_xlabel('Epochs')
        ax.legend(loc="upper left")
    
    plt.tight_layout()
    plt.show()

# %%
os.getcwd()
# Out:
# '/teamspace/studios/this_studio/EFlow Images/btagged_images_CNN'

# %%
# signal_main = pd.read_csv('/teamspace/studios/this_studio/Preprocessing Eflow Images/data/dataset3/sig_btagged2jets.txt', sep = '\t')
# background_main = pd.read_csv('/teamspace/studios/this_studio/Preprocessing Eflow Images/data/dataset3/bg_btagged2jets.txt', sep = '\t')

# %%
# columns = ['isophoton_Eta', 'isophoton_Phi', 'jet1_Eta', 'jet1_Phi', 'jet2_Eta', 'jet2_Phi']

# %%
# signal = signal_main[columns]
# background = background_main[columns]

# %%
signal = pd.read_csv('/teamspace/studios/this_studio/BDT/data/signal_bdt.txt', sep = '\t')
background = pd.read_csv('/teamspace/studios/this_studio/BDT/data/background_bdt.txt', sep = '\t')

# %%
data = pd.concat([signal, background], axis = 0)

## Shuffling the data
data = data.sample(frac=1, random_state=seed)

# %%
data.values
# Out:
# array([[ 32.1602    ,   4.58691831, 101.12352354,   1.        ],
#        [ 67.4479    ,   5.68637488, 325.61130819,   0.        ],
#        [ 49.7301    ,   1.14533664, 141.37874342,   0.        ],
#        ...,
#        [ 67.0442    ,   3.67697228, 167.17726366,   1.        ],
#        [ 36.5321    ,   4.39180638, 104.95613426,   1.        ],
#        [ 39.5457    ,   3.38669265, 237.92337605,   0.        ]])

# %%
X, y = data.values[:,:-1], data.values[:,-1]

# %%
train_size = int(len(data)*.7) #70% of total batches as training data
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

X_train, y_train = X[:train_size, :], y[:train_size]
X_test, y_test = X[train_size:(train_size+test_size), :], y[train_size:(train_size+test_size)]
X_val, y_val = X[(train_size+test_size):, :], y[(train_size+test_size):]

# %%
train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test = tf.data.Dataset.from_tensor_slices((X_test, y_test))
val = tf.data.Dataset.from_tensor_slices((X_val, y_val))

# %%
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test.batch(BATCH_SIZE)
val_dataset = val.batch(BATCH_SIZE)

# %% [markdown]
# # Model

# %%
inputs = Input(shape=(3,))
x = Flatten()(inputs)
x = Dense(64, activation='relu')(x)
#x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
#x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
#x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
#x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)

ann = tf.keras.Model(inputs=inputs, outputs=outputs)
ann.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 3)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 3)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 337,537 (1.29 MB)
#  Trainable params: 337,537 (1.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
ann.compile('adam', 
              loss=tf.losses.BinaryCrossentropy(), 
              metrics=['accuracy',
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       tf.keras.metrics.AUC(),
                       tf.keras.metrics.TruePositives(),
                       tf.keras.metrics.FalsePositives(),
                       tf.keras.metrics.TrueNegatives(),
                       tf.keras.metrics.FalseNegatives()])

logdir = '/teamspace/studios/this_studio/EFlow Images/btagged_images_CNN/ann'

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

checkpoint_callback = ModelCheckpoint(
    filepath='ann.keras',
    save_weights_only=False,
    monitor='val_auc',              
    mode='auto',           
    save_best_only=True,
    verbose=2
)


ann_hist = ann.fit(train_dataset,
                 epochs = 100,
                 validation_data = val_dataset, 
                 callbacks = [tensorboard_callback, checkpoint_callback])
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5553 - auc_6: 0.5337 - false_negatives_6: 240.3571 - false_positives_6: 150.0000 - loss: 1.6432 - precision_6: 0.4115 - recall_6: 0.3202 - true_negatives_6: 418.6786 - true_positives_6: 113.9643 - val_accuracy: 0.6653 - val_auc_6: 0.7791 - val_false_negatives_6: 162.0000 - val_false_positives_6: 0.0000e+00 - val_loss: 0.5673 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00 - val_true_negatives_6: 322.0000 - val_true_positives_6: 0.0000e+00
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6193 - auc_6: 0.6705 - false_negatives_6: 283.5000 - false_positives_6: 55.7857 - loss: 0.6742 - precision_6: 0.5208 - recall_6: 0.1661 - true_negatives_6: 509.8929 - true_positives_6: 73.8214 - val_accuracy: 0.6777 - val_auc_6: 0.7604 - val_false_negatives_6: 133.0000 - val_false_positives_6: 23.0000 - val_loss: 0.5552 - val_precision_6: 0.5577 - val_recall_6: 0.1790 - val_true_negatives_6: 299.0000 - val_true_positives_6: 29.0000
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6612 - auc_6: 0.7288 - false_negatives_6: 236.2500 - false_positives_6: 70.1429 - loss: 0.6304 - precision_6: 0.6389 - recall_6: 0.3127 - true_negatives_6: 495.8929 - true_positives_6: 120.7143 - val_accuracy: 0.6674 - val_auc_6: 0.8137 - val_false_negatives_6: 161.0000 - val_false_positives_6: 0.0000e+00 - val_loss: 0.5493 - val_precision_6: 1.0000 - val_recall_6: 0.0062 - val_true_negatives_6: 322.0000 - val_true_positives_6: 1.0000
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6757 - auc_6: 0.7429 - false_negatives_6: 228.3571 - false_positives_6: 58.7500 - loss: 0.6142 - precision_6: 0.6931 - recall_6: 0.3141 - true_negatives_6: 506.8214 - true_positives_6: 129.0714 - val_accuracy: 0.7417 - val_auc_6: 0.8025 - val_false_negatives_6: 104.0000 - val_false_positives_6: 21.0000 - val_loss: 0.5430 - val_precision_6: 0.7342 - val_recall_6: 0.3580 - val_true_negatives_6: 301.0000 - val_true_positives_6: 58.0000
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7106 - auc_6: 0.7697 - false_negatives_6: 185.6071 - false_positives_6: 69.8929 - loss: 0.5909 - precision_6: 0.7169 - recall_6: 0.4263 - true_negatives_6: 500.0714 - true_positives_6: 167.4286 - val_accuracy: 0.7397 - val_auc_6: 0.7886 - val_false_negatives_6: 71.0000 - val_false_positives_6: 55.0000 - val_loss: 0.5689 - val_precision_6: 0.6233 - val_recall_6: 0.5617 - val_true_negatives_6: 267.0000 - val_true_positives_6: 91.0000
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7076 - auc_6: 0.7617 - false_negatives_6: 183.1071 - false_positives_6: 76.2857 - loss: 0.5913 - precision_6: 0.7016 - recall_6: 0.4456 - true_negatives_6: 490.9643 - true_positives_6: 172.6429 - val_accuracy: 0.7624 - val_auc_6: 0.8128 - val_false_negatives_6: 91.0000 - val_false_positives_6: 24.0000 - val_loss: 0.5365 - val_precision_6: 0.7474 - val_recall_6: 0.4383 - val_true_negatives_6: 298.0000 - val_true_positives_6: 71.0000
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7353 - auc_6: 0.7746 - false_negatives_6: 164.8929 - false_positives_6: 76.2143 - loss: 0.5959 - precision_6: 0.7399 - recall_6: 0.5037 - true_negatives_6: 491.2143 - true_positives_6: 190.6786 - val_accuracy: 0.6983 - val_auc_6: 0.8218 - val_false_negatives_6: 144.0000 - val_false_positives_6: 2.0000 - val_loss: 0.5317 - val_precision_6: 0.9000 - val_recall_6: 0.1111 - val_true_negatives_6: 320.0000 - val_true_positives_6: 18.0000
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6998 - auc_6: 0.7449 - false_negatives_6: 183.3214 - false_positives_6: 87.2857 - loss: 0.6101 - precision_6: 0.6986 - recall_6: 0.4300 - true_negatives_6: 479.1786 - true_positives_6: 173.2143 - val_accuracy: 0.7789 - val_auc_6: 0.8283 - val_false_negatives_6: 95.0000 - val_false_positives_6: 12.0000 - val_loss: 0.5395 - val_precision_6: 0.8481 - val_recall_6: 0.4136 - val_true_negatives_6: 310.0000 - val_true_positives_6: 67.0000
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7196 - auc_6: 0.7773 - false_negatives_6: 173.8571 - false_positives_6: 78.6071 - loss: 0.5827 - precision_6: 0.7172 - recall_6: 0.4657 - true_negatives_6: 490.5714 - true_positives_6: 179.9643 - val_accuracy: 0.7562 - val_auc_6: 0.8087 - val_false_negatives_6: 51.0000 - val_false_positives_6: 67.0000 - val_loss: 0.5414 - val_precision_6: 0.6236 - val_recall_6: 0.6852 - val_true_negatives_6: 255.0000 - val_true_positives_6: 111.0000
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7401 - auc_6: 0.7972 - false_negatives_6: 153.3571 - false_positives_6: 86.0000 - loss: 0.5595 - precision_6: 0.7054 - recall_6: 0.5726 - true_negatives_6: 481.9643 - true_positives_6: 201.6786 - val_accuracy: 0.6694 - val_auc_6: 0.7437 - val_false_negatives_6: 159.0000 - val_false_positives_6: 1.0000 - val_loss: 0.5689 - val_precision_6: 0.7500 - val_recall_6: 0.0185 - val_true_negatives_6: 321.0000 - val_true_positives_6: 3.0000
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7086 - auc_6: 0.7625 - false_negatives_6: 193.3214 - false_positives_6: 61.5357 - loss: 0.5990 - precision_6: 0.7742 - recall_6: 0.3971 - true_negatives_6: 504.8929 - true_positives_6: 163.2500 - val_accuracy: 0.7831 - val_auc_6: 0.8229 - val_false_negatives_6: 75.0000 - val_false_positives_6: 30.0000 - val_loss: 0.5136 - val_precision_6: 0.7436 - val_recall_6: 0.5370 - val_true_negatives_6: 292.0000 - val_true_positives_6: 87.0000
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7586 - auc_6: 0.8075 - false_negatives_6: 151.3929 - false_positives_6: 68.3571 - loss: 0.5424 - precision_6: 0.7600 - recall_6: 0.5593 - true_negatives_6: 498.8571 - true_positives_6: 204.3929 - val_accuracy: 0.7789 - val_auc_6: 0.8253 - val_false_negatives_6: 75.0000 - val_false_positives_6: 32.0000 - val_loss: 0.4995 - val_precision_6: 0.7311 - val_recall_6: 0.5370 - val_true_negatives_6: 290.0000 - val_true_positives_6: 87.0000
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7622 - auc_6: 0.8023 - false_negatives_6: 151.4286 - false_positives_6: 62.7857 - loss: 0.5404 - precision_6: 0.7697 - recall_6: 0.5658 - true_negatives_6: 504.2143 - true_positives_6: 204.5714 - val_accuracy: 0.7707 - val_auc_6: 0.8286 - val_false_negatives_6: 99.0000 - val_false_positives_6: 12.0000 - val_loss: 0.5065 - val_precision_6: 0.8400 - val_recall_6: 0.3889 - val_true_negatives_6: 310.0000 - val_true_positives_6: 63.0000
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7478 - auc_6: 0.7942 - false_negatives_6: 159.8571 - false_positives_6: 65.7500 - loss: 0.5545 - precision_6: 0.7636 - recall_6: 0.5200 - true_negatives_6: 503.1786 - true_positives_6: 194.2143 - val_accuracy: 0.7417 - val_auc_6: 0.8286 - val_false_negatives_6: 116.0000 - val_false_positives_6: 9.0000 - val_loss: 0.5205 - val_precision_6: 0.8364 - val_recall_6: 0.2840 - val_true_negatives_6: 313.0000 - val_true_positives_6: 46.0000
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7531 - auc_6: 0.7943 - false_negatives_6: 168.5000 - false_positives_6: 54.4643 - loss: 0.5565 - precision_6: 0.7894 - recall_6: 0.4981 - true_negatives_6: 515.3929 - true_positives_6: 184.6429 - val_accuracy: 0.7789 - val_auc_6: 0.8333 - val_false_negatives_6: 84.0000 - val_false_positives_6: 23.0000 - val_loss: 0.4875 - val_precision_6: 0.7723 - val_recall_6: 0.4815 - val_true_negatives_6: 299.0000 - val_true_positives_6: 78.0000
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7683 - auc_6: 0.8044 - false_negatives_6: 145.1786 - false_positives_6: 65.4286 - loss: 0.5384 - precision_6: 0.7671 - recall_6: 0.5894 - true_negatives_6: 502.2857 - true_positives_6: 210.1071 - val_accuracy: 0.7831 - val_auc_6: 0.8225 - val_false_negatives_6: 86.0000 - val_false_positives_6: 19.0000 - val_loss: 0.5087 - val_precision_6: 0.8000 - val_recall_6: 0.4691 - val_true_negatives_6: 303.0000 - val_true_positives_6: 76.0000
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7555 - auc_6: 0.7980 - false_negatives_6: 154.4643 - false_positives_6: 65.1429 - loss: 0.5493 - precision_6: 0.7792 - recall_6: 0.5262 - true_negatives_6: 502.2857 - true_positives_6: 201.1071 - val_accuracy: 0.7748 - val_auc_6: 0.8282 - val_false_negatives_6: 64.0000 - val_false_positives_6: 45.0000 - val_loss: 0.4867 - val_precision_6: 0.6853 - val_recall_6: 0.6049 - val_true_negatives_6: 277.0000 - val_true_positives_6: 98.0000
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7496 - auc_6: 0.7917 - false_negatives_6: 177.3571 - false_positives_6: 53.4643 - loss: 0.5442 - precision_6: 0.7774 - recall_6: 0.5027 - true_negatives_6: 513.9643 - true_positives_6: 178.2143 - val_accuracy: 0.7583 - val_auc_6: 0.8122 - val_false_negatives_6: 39.0000 - val_false_positives_6: 78.0000 - val_loss: 0.5245 - val_precision_6: 0.6119 - val_recall_6: 0.7593 - val_true_negatives_6: 244.0000 - val_true_positives_6: 123.0000
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7748 - auc_6: 0.8161 - false_negatives_6: 135.0357 - false_positives_6: 76.7143 - loss: 0.5221 - precision_6: 0.7496 - recall_6: 0.6302 - true_negatives_6: 491.4643 - true_positives_6: 219.7857 - val_accuracy: 0.7913 - val_auc_6: 0.8332 - val_false_negatives_6: 69.0000 - val_false_positives_6: 32.0000 - val_loss: 0.4845 - val_precision_6: 0.7440 - val_recall_6: 0.5741 - val_true_negatives_6: 290.0000 - val_true_positives_6: 93.0000
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7621 - auc_6: 0.8048 - false_negatives_6: 159.6071 - false_positives_6: 54.7500 - loss: 0.5258 - precision_6: 0.7842 - recall_6: 0.5344 - true_negatives_6: 513.8929 - true_positives_6: 194.7500 - val_accuracy: 0.7872 - val_auc_6: 0.8348 - val_false_negatives_6: 69.0000 - val_false_positives_6: 34.0000 - val_loss: 0.4809 - val_precision_6: 0.7323 - val_recall_6: 0.5741 - val_true_negatives_6: 288.0000 - val_true_positives_6: 93.0000
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7684 - auc_6: 0.8042 - false_negatives_6: 162.6429 - false_positives_6: 50.0357 - loss: 0.5232 - precision_6: 0.8038 - recall_6: 0.5339 - true_negatives_6: 518.4643 - true_positives_6: 191.8571 - val_accuracy: 0.7851 - val_auc_6: 0.8339 - val_false_negatives_6: 81.0000 - val_false_positives_6: 23.0000 - val_loss: 0.4966 - val_precision_6: 0.7788 - val_recall_6: 0.5000 - val_true_negatives_6: 299.0000 - val_true_positives_6: 81.0000
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7640 - auc_6: 0.8103 - false_negatives_6: 158.3571 - false_positives_6: 56.7857 - loss: 0.5290 - precision_6: 0.7990 - recall_6: 0.5387 - true_negatives_6: 511.0714 - true_positives_6: 196.7857 - val_accuracy: 0.7624 - val_auc_6: 0.8155 - val_false_negatives_6: 40.0000 - val_false_positives_6: 75.0000 - val_loss: 0.5106 - val_precision_6: 0.6193 - val_recall_6: 0.7531 - val_true_negatives_6: 247.0000 - val_true_positives_6: 122.0000
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7731 - auc_6: 0.8123 - false_negatives_6: 133.2143 - false_positives_6: 76.2500 - loss: 0.5170 - precision_6: 0.7484 - recall_6: 0.6317 - true_negatives_6: 492.2857 - true_positives_6: 221.2500 - val_accuracy: 0.7810 - val_auc_6: 0.8298 - val_false_negatives_6: 68.0000 - val_false_positives_6: 38.0000 - val_loss: 0.4844 - val_precision_6: 0.7121 - val_recall_6: 0.5802 - val_true_negatives_6: 284.0000 - val_true_positives_6: 94.0000
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7674 - auc_6: 0.8096 - false_negatives_6: 159.1786 - false_positives_6: 53.3929 - loss: 0.5180 - precision_6: 0.7939 - recall_6: 0.5386 - true_negatives_6: 514.7857 - true_positives_6: 195.6429 - val_accuracy: 0.7789 - val_auc_6: 0.8273 - val_false_negatives_6: 69.0000 - val_false_positives_6: 38.0000 - val_loss: 0.4824 - val_precision_6: 0.7099 - val_recall_6: 0.5741 - val_true_negatives_6: 284.0000 - val_true_positives_6: 93.0000
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7632 - auc_6: 0.8189 - false_negatives_6: 163.1429 - false_positives_6: 51.1429 - loss: 0.5070 - precision_6: 0.7976 - recall_6: 0.5307 - true_negatives_6: 516.3929 - true_positives_6: 192.3214 - val_accuracy: 0.7810 - val_auc_6: 0.8339 - val_false_negatives_6: 72.0000 - val_false_positives_6: 34.0000 - val_loss: 0.4817 - val_precision_6: 0.7258 - val_recall_6: 0.5556 - val_true_negatives_6: 288.0000 - val_true_positives_6: 90.0000
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7649 - auc_6: 0.8092 - false_negatives_6: 158.3214 - false_positives_6: 56.3214 - loss: 0.5219 - precision_6: 0.7901 - recall_6: 0.5346 - true_negatives_6: 512.1429 - true_positives_6: 196.2143 - val_accuracy: 0.7831 - val_auc_6: 0.8225 - val_false_negatives_6: 45.0000 - val_false_positives_6: 60.0000 - val_loss: 0.4977 - val_precision_6: 0.6610 - val_recall_6: 0.7222 - val_true_negatives_6: 262.0000 - val_true_positives_6: 117.0000
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7696 - auc_6: 0.8182 - false_negatives_6: 146.2857 - false_positives_6: 66.1429 - loss: 0.5038 - precision_6: 0.7631 - recall_6: 0.5828 - true_negatives_6: 502.1071 - true_positives_6: 208.4643 - val_accuracy: 0.7810 - val_auc_6: 0.8252 - val_false_negatives_6: 57.0000 - val_false_positives_6: 49.0000 - val_loss: 0.4912 - val_precision_6: 0.6818 - val_recall_6: 0.6481 - val_true_negatives_6: 273.0000 - val_true_positives_6: 105.0000
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7612 - auc_6: 0.8157 - false_negatives_6: 158.4643 - false_positives_6: 55.9286 - loss: 0.5062 - precision_6: 0.7773 - recall_6: 0.5380 - true_negatives_6: 512.6429 - true_positives_6: 195.9643 - val_accuracy: 0.7789 - val_auc_6: 0.8273 - val_false_negatives_6: 65.0000 - val_false_positives_6: 42.0000 - val_loss: 0.4817 - val_precision_6: 0.6978 - val_recall_6: 0.5988 - val_true_negatives_6: 280.0000 - val_true_positives_6: 97.0000
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7653 - auc_6: 0.8108 - false_negatives_6: 163.8571 - false_positives_6: 49.8571 - loss: 0.5133 - precision_6: 0.8026 - recall_6: 0.5292 - true_negatives_6: 517.3214 - true_positives_6: 191.9643 - val_accuracy: 0.7831 - val_auc_6: 0.8325 - val_false_negatives_6: 79.0000 - val_false_positives_6: 26.0000 - val_loss: 0.4785 - val_precision_6: 0.7615 - val_recall_6: 0.5123 - val_true_negatives_6: 296.0000 - val_true_positives_6: 83.0000
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7563 - auc_6: 0.8217 - false_negatives_6: 162.1786 - false_positives_6: 55.8214 - loss: 0.5088 - precision_6: 0.8059 - recall_6: 0.5054 - true_negatives_6: 510.8214 - true_positives_6: 194.1786 - val_accuracy: 0.7769 - val_auc_6: 0.8351 - val_false_negatives_6: 70.0000 - val_false_positives_6: 38.0000 - val_loss: 0.4780 - val_precision_6: 0.7077 - val_recall_6: 0.5679 - val_true_negatives_6: 284.0000 - val_true_positives_6: 92.0000
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7160 - auc_6: 0.7956 - false_negatives_6: 208.3929 - false_positives_6: 50.0000 - loss: 0.5444 - precision_6: 0.7753 - recall_6: 0.3833 - true_negatives_6: 516.3571 - true_positives_6: 148.2500 - val_accuracy: 0.7831 - val_auc_6: 0.8326 - val_false_negatives_6: 84.0000 - val_false_positives_6: 21.0000 - val_loss: 0.4841 - val_precision_6: 0.7879 - val_recall_6: 0.4815 - val_true_negatives_6: 301.0000 - val_true_positives_6: 78.0000
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7592 - auc_6: 0.8131 - false_negatives_6: 168.1071 - false_positives_6: 49.3571 - loss: 0.5101 - precision_6: 0.8066 - recall_6: 0.5039 - true_negatives_6: 518.8571 - true_positives_6: 186.6786 - val_accuracy: 0.7810 - val_auc_6: 0.8331 - val_false_negatives_6: 63.0000 - val_false_positives_6: 43.0000 - val_loss: 0.4731 - val_precision_6: 0.6972 - val_recall_6: 0.6111 - val_true_negatives_6: 279.0000 - val_true_positives_6: 99.0000
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7747 - auc_6: 0.8237 - false_negatives_6: 148.5357 - false_positives_6: 56.9286 - loss: 0.4961 - precision_6: 0.7857 - recall_6: 0.5756 - true_negatives_6: 511.2143 - true_positives_6: 206.3214 - val_accuracy: 0.7872 - val_auc_6: 0.8329 - val_false_negatives_6: 79.0000 - val_false_positives_6: 24.0000 - val_loss: 0.4915 - val_precision_6: 0.7757 - val_recall_6: 0.5123 - val_true_negatives_6: 298.0000 - val_true_positives_6: 83.0000
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7662 - auc_6: 0.8149 - false_negatives_6: 166.4643 - false_positives_6: 45.6786 - loss: 0.5097 - precision_6: 0.8249 - recall_6: 0.5021 - true_negatives_6: 523.4286 - true_positives_6: 187.4286 - val_accuracy: 0.7893 - val_auc_6: 0.8345 - val_false_negatives_6: 58.0000 - val_false_positives_6: 44.0000 - val_loss: 0.4719 - val_precision_6: 0.7027 - val_recall_6: 0.6420 - val_true_negatives_6: 278.0000 - val_true_positives_6: 104.0000
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7767 - auc_6: 0.8232 - false_negatives_6: 137.8929 - false_positives_6: 65.3571 - loss: 0.4995 - precision_6: 0.7727 - recall_6: 0.6002 - true_negatives_6: 502.6786 - true_positives_6: 217.0714 - val_accuracy: 0.7831 - val_auc_6: 0.8285 - val_false_negatives_6: 52.0000 - val_false_positives_6: 53.0000 - val_loss: 0.4978 - val_precision_6: 0.6748 - val_recall_6: 0.6790 - val_true_negatives_6: 269.0000 - val_true_positives_6: 110.0000
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7723 - auc_6: 0.8289 - false_negatives_6: 147.7143 - false_positives_6: 61.1429 - loss: 0.4876 - precision_6: 0.7764 - recall_6: 0.5906 - true_negatives_6: 505.7143 - true_positives_6: 208.4286 - val_accuracy: 0.7851 - val_auc_6: 0.8322 - val_false_negatives_6: 57.0000 - val_false_positives_6: 47.0000 - val_loss: 0.4910 - val_precision_6: 0.6908 - val_recall_6: 0.6481 - val_true_negatives_6: 275.0000 - val_true_positives_6: 105.0000
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7693 - auc_6: 0.8178 - false_negatives_6: 152.0714 - false_positives_6: 54.6071 - loss: 0.4990 - precision_6: 0.7847 - recall_6: 0.5602 - true_negatives_6: 515.1071 - true_positives_6: 201.2143 - val_accuracy: 0.7872 - val_auc_6: 0.8354 - val_false_negatives_6: 59.0000 - val_false_positives_6: 44.0000 - val_loss: 0.4748 - val_precision_6: 0.7007 - val_recall_6: 0.6358 - val_true_negatives_6: 278.0000 - val_true_positives_6: 103.0000
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7748 - auc_6: 0.8214 - false_negatives_6: 144.7500 - false_positives_6: 60.3571 - loss: 0.4984 - precision_6: 0.7777 - recall_6: 0.5871 - true_negatives_6: 508.1429 - true_positives_6: 209.7500 - val_accuracy: 0.7955 - val_auc_6: 0.8331 - val_false_negatives_6: 51.0000 - val_false_positives_6: 48.0000 - val_loss: 0.4844 - val_precision_6: 0.6981 - val_recall_6: 0.6852 - val_true_negatives_6: 274.0000 - val_true_positives_6: 111.0000
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7698 - auc_6: 0.8240 - false_negatives_6: 146.9643 - false_positives_6: 61.4643 - loss: 0.4965 - precision_6: 0.7723 - recall_6: 0.5806 - true_negatives_6: 505.1071 - true_positives_6: 209.4643 - val_accuracy: 0.7893 - val_auc_6: 0.8356 - val_false_negatives_6: 61.0000 - val_false_positives_6: 41.0000 - val_loss: 0.4799 - val_precision_6: 0.7113 - val_recall_6: 0.6235 - val_true_negatives_6: 281.0000 - val_true_positives_6: 101.0000
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7675 - auc_6: 0.8210 - false_negatives_6: 155.0714 - false_positives_6: 53.7143 - loss: 0.4970 - precision_6: 0.7861 - recall_6: 0.5447 - true_negatives_6: 514.4286 - true_positives_6: 199.7857 - val_accuracy: 0.7934 - val_auc_6: 0.8375 - val_false_negatives_6: 51.0000 - val_false_positives_6: 49.0000 - val_loss: 0.4821 - val_precision_6: 0.6938 - val_recall_6: 0.6852 - val_true_negatives_6: 273.0000 - val_true_positives_6: 111.0000
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7706 - auc_6: 0.8143 - false_negatives_6: 150.8571 - false_positives_6: 58.3571 - loss: 0.5003 - precision_6: 0.7786 - recall_6: 0.5718 - true_negatives_6: 507.7857 - true_positives_6: 206.0000 - val_accuracy: 0.7955 - val_auc_6: 0.8334 - val_false_negatives_6: 56.0000 - val_false_positives_6: 43.0000 - val_loss: 0.4800 - val_precision_6: 0.7114 - val_recall_6: 0.6543 - val_true_negatives_6: 279.0000 - val_true_positives_6: 106.0000
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7798 - auc_6: 0.8250 - false_negatives_6: 133.8929 - false_positives_6: 65.6786 - loss: 0.4912 - precision_6: 0.7788 - recall_6: 0.6118 - true_negatives_6: 504.1429 - true_positives_6: 219.2857 - val_accuracy: 0.7955 - val_auc_6: 0.8356 - val_false_negatives_6: 54.0000 - val_false_positives_6: 45.0000 - val_loss: 0.4879 - val_precision_6: 0.7059 - val_recall_6: 0.6667 - val_true_negatives_6: 277.0000 - val_true_positives_6: 108.0000
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7783 - auc_6: 0.8225 - false_negatives_6: 143.1071 - false_positives_6: 58.8571 - loss: 0.4907 - precision_6: 0.7809 - recall_6: 0.5943 - true_negatives_6: 509.0357 - true_positives_6: 212.0000 - val_accuracy: 0.7975 - val_auc_6: 0.8377 - val_false_negatives_6: 56.0000 - val_false_positives_6: 42.0000 - val_loss: 0.4746 - val_precision_6: 0.7162 - val_recall_6: 0.6543 - val_true_negatives_6: 280.0000 - val_true_positives_6: 106.0000
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7742 - auc_6: 0.8286 - false_negatives_6: 146.5714 - false_positives_6: 57.2143 - loss: 0.4918 - precision_6: 0.7906 - recall_6: 0.5743 - true_negatives_6: 510.1786 - true_positives_6: 209.0357 - val_accuracy: 0.7955 - val_auc_6: 0.8344 - val_false_negatives_6: 47.0000 - val_false_positives_6: 52.0000 - val_loss: 0.4903 - val_precision_6: 0.6886 - val_recall_6: 0.7099 - val_true_negatives_6: 270.0000 - val_true_positives_6: 115.0000
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7856 - auc_6: 0.8237 - false_negatives_6: 137.2143 - false_positives_6: 61.6071 - loss: 0.4931 - precision_6: 0.7904 - recall_6: 0.6186 - true_negatives_6: 505.1071 - true_positives_6: 219.0714 - val_accuracy: 0.7872 - val_auc_6: 0.8369 - val_false_negatives_6: 46.0000 - val_false_positives_6: 57.0000 - val_loss: 0.5003 - val_precision_6: 0.6705 - val_recall_6: 0.7160 - val_true_negatives_6: 265.0000 - val_true_positives_6: 116.0000
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7808 - auc_6: 0.8379 - false_negatives_6: 142.1429 - false_positives_6: 59.4643 - loss: 0.4845 - precision_6: 0.7820 - recall_6: 0.6020 - true_negatives_6: 508.4286 - true_positives_6: 212.9643 - val_accuracy: 0.7934 - val_auc_6: 0.8316 - val_false_negatives_6: 62.0000 - val_false_positives_6: 38.0000 - val_loss: 0.4759 - val_precision_6: 0.7246 - val_recall_6: 0.6173 - val_true_negatives_6: 284.0000 - val_true_positives_6: 100.0000
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7726 - auc_6: 0.8262 - false_negatives_6: 141.6071 - false_positives_6: 62.9286 - loss: 0.4915 - precision_6: 0.7720 - recall_6: 0.5879 - true_negatives_6: 504.6786 - true_positives_6: 213.7857 - val_accuracy: 0.7851 - val_auc_6: 0.8380 - val_false_negatives_6: 70.0000 - val_false_positives_6: 34.0000 - val_loss: 0.4768 - val_precision_6: 0.7302 - val_recall_6: 0.5679 - val_true_negatives_6: 288.0000 - val_true_positives_6: 92.0000
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7760 - auc_6: 0.8259 - false_negatives_6: 155.6786 - false_positives_6: 46.7143 - loss: 0.4946 - precision_6: 0.8234 - recall_6: 0.5485 - true_negatives_6: 520.0000 - true_positives_6: 200.6071 - val_accuracy: 0.8017 - val_auc_6: 0.8389 - val_false_negatives_6: 56.0000 - val_false_positives_6: 40.0000 - val_loss: 0.4745 - val_precision_6: 0.7260 - val_recall_6: 0.6543 - val_true_negatives_6: 282.0000 - val_true_positives_6: 106.0000
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7787 - auc_6: 0.8255 - false_negatives_6: 135.8214 - false_positives_6: 68.6071 - loss: 0.4893 - precision_6: 0.7744 - recall_6: 0.6148 - true_negatives_6: 497.4286 - true_positives_6: 221.1429 - val_accuracy: 0.7810 - val_auc_6: 0.8374 - val_false_negatives_6: 70.0000 - val_false_positives_6: 36.0000 - val_loss: 0.4698 - val_precision_6: 0.7188 - val_recall_6: 0.5679 - val_true_negatives_6: 286.0000 - val_true_positives_6: 92.0000
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7681 - auc_6: 0.8240 - false_negatives_6: 161.8571 - false_positives_6: 49.7857 - loss: 0.4951 - precision_6: 0.8051 - recall_6: 0.5249 - true_negatives_6: 520.1071 - true_positives_6: 191.2500 - val_accuracy: 0.7975 - val_auc_6: 0.8315 - val_false_negatives_6: 55.0000 - val_false_positives_6: 43.0000 - val_loss: 0.4861 - val_precision_6: 0.7133 - val_recall_6: 0.6605 - val_true_negatives_6: 279.0000 - val_true_positives_6: 107.0000
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7774 - auc_6: 0.8307 - false_negatives_6: 154.6071 - false_positives_6: 49.0357 - loss: 0.4868 - precision_6: 0.8060 - recall_6: 0.5576 - true_negatives_6: 518.1071 - true_positives_6: 201.2500 - val_accuracy: 0.7934 - val_auc_6: 0.8341 - val_false_negatives_6: 59.0000 - val_false_positives_6: 41.0000 - val_loss: 0.4836 - val_precision_6: 0.7153 - val_recall_6: 0.6358 - val_true_negatives_6: 281.0000 - val_true_positives_6: 103.0000
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7831 - auc_6: 0.8305 - false_negatives_6: 144.9286 - false_positives_6: 53.0714 - loss: 0.4871 - precision_6: 0.8002 - recall_6: 0.5850 - true_negatives_6: 516.0714 - true_positives_6: 208.9286 - val_accuracy: 0.8058 - val_auc_6: 0.8384 - val_false_negatives_6: 58.0000 - val_false_positives_6: 36.0000 - val_loss: 0.4681 - val_precision_6: 0.7429 - val_recall_6: 0.6420 - val_true_negatives_6: 286.0000 - val_true_positives_6: 104.0000
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7744 - auc_6: 0.8247 - false_negatives_6: 153.2500 - false_positives_6: 53.5000 - loss: 0.4926 - precision_6: 0.8035 - recall_6: 0.5542 - true_negatives_6: 514.1786 - true_positives_6: 202.0714 - val_accuracy: 0.8058 - val_auc_6: 0.8378 - val_false_negatives_6: 50.0000 - val_false_positives_6: 44.0000 - val_loss: 0.4839 - val_precision_6: 0.7179 - val_recall_6: 0.6914 - val_true_negatives_6: 278.0000 - val_true_positives_6: 112.0000
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7737 - auc_6: 0.8202 - false_negatives_6: 144.9643 - false_positives_6: 55.7857 - loss: 0.4974 - precision_6: 0.7856 - recall_6: 0.5762 - true_negatives_6: 512.5000 - true_positives_6: 209.7500 - val_accuracy: 0.8037 - val_auc_6: 0.8390 - val_false_negatives_6: 56.0000 - val_false_positives_6: 39.0000 - val_loss: 0.4742 - val_precision_6: 0.7310 - val_recall_6: 0.6543 - val_true_negatives_6: 283.0000 - val_true_positives_6: 106.0000
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7825 - auc_6: 0.8201 - false_negatives_6: 148.9643 - false_positives_6: 50.6071 - loss: 0.4914 - precision_6: 0.8041 - recall_6: 0.5732 - true_negatives_6: 517.2500 - true_positives_6: 206.1786 - val_accuracy: 0.7872 - val_auc_6: 0.8349 - val_false_negatives_6: 71.0000 - val_false_positives_6: 32.0000 - val_loss: 0.4750 - val_precision_6: 0.7398 - val_recall_6: 0.5617 - val_true_negatives_6: 290.0000 - val_true_positives_6: 91.0000
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7695 - auc_6: 0.8357 - false_negatives_6: 147.8929 - false_positives_6: 57.0357 - loss: 0.4839 - precision_6: 0.7905 - recall_6: 0.5611 - true_negatives_6: 509.4643 - true_positives_6: 208.6071 - val_accuracy: 0.8079 - val_auc_6: 0.8363 - val_false_negatives_6: 52.0000 - val_false_positives_6: 41.0000 - val_loss: 0.4752 - val_precision_6: 0.7285 - val_recall_6: 0.6790 - val_true_negatives_6: 281.0000 - val_true_positives_6: 110.0000
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7785 - auc_6: 0.8307 - false_negatives_6: 139.6429 - false_positives_6: 62.5714 - loss: 0.4859 - precision_6: 0.7766 - recall_6: 0.5986 - true_negatives_6: 504.9643 - true_positives_6: 215.8214 - val_accuracy: 0.8079 - val_auc_6: 0.8361 - val_false_negatives_6: 45.0000 - val_false_positives_6: 48.0000 - val_loss: 0.4876 - val_precision_6: 0.7091 - val_recall_6: 0.7222 - val_true_negatives_6: 274.0000 - val_true_positives_6: 117.0000
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7840 - auc_6: 0.8341 - false_negatives_6: 147.5000 - false_positives_6: 52.0357 - loss: 0.4800 - precision_6: 0.8096 - recall_6: 0.5748 - true_negatives_6: 516.0357 - true_positives_6: 207.4286 - val_accuracy: 0.8120 - val_auc_6: 0.8362 - val_false_negatives_6: 49.0000 - val_false_positives_6: 42.0000 - val_loss: 0.4759 - val_precision_6: 0.7290 - val_recall_6: 0.6975 - val_true_negatives_6: 280.0000 - val_true_positives_6: 113.0000
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7869 - auc_6: 0.8401 - false_negatives_6: 137.0357 - false_positives_6: 57.7857 - loss: 0.4701 - precision_6: 0.7883 - recall_6: 0.6121 - true_negatives_6: 511.1429 - true_positives_6: 217.0357 - val_accuracy: 0.7810 - val_auc_6: 0.8369 - val_false_negatives_6: 78.0000 - val_false_positives_6: 28.0000 - val_loss: 0.4625 - val_precision_6: 0.7500 - val_recall_6: 0.5185 - val_true_negatives_6: 294.0000 - val_true_positives_6: 84.0000
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7706 - auc_6: 0.8307 - false_negatives_6: 156.2500 - false_positives_6: 51.8571 - loss: 0.4881 - precision_6: 0.8149 - recall_6: 0.5363 - true_negatives_6: 517.0714 - true_positives_6: 197.8214 - val_accuracy: 0.8079 - val_auc_6: 0.8380 - val_false_negatives_6: 48.0000 - val_false_positives_6: 45.0000 - val_loss: 0.4818 - val_precision_6: 0.7170 - val_recall_6: 0.7037 - val_true_negatives_6: 277.0000 - val_true_positives_6: 114.0000
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7816 - auc_6: 0.8291 - false_negatives_6: 141.5714 - false_positives_6: 57.6071 - loss: 0.4812 - precision_6: 0.7874 - recall_6: 0.5949 - true_negatives_6: 511.8929 - true_positives_6: 211.9286 - val_accuracy: 0.8058 - val_auc_6: 0.8405 - val_false_negatives_6: 53.0000 - val_false_positives_6: 41.0000 - val_loss: 0.4760 - val_precision_6: 0.7267 - val_recall_6: 0.6728 - val_true_negatives_6: 281.0000 - val_true_positives_6: 109.0000
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7965 - auc_6: 0.8425 - false_negatives_6: 138.8571 - false_positives_6: 53.2500 - loss: 0.4658 - precision_6: 0.8139 - recall_6: 0.6122 - true_negatives_6: 515.3214 - true_positives_6: 215.5714 - val_accuracy: 0.7913 - val_auc_6: 0.8386 - val_false_negatives_6: 45.0000 - val_false_positives_6: 56.0000 - val_loss: 0.4842 - val_precision_6: 0.6763 - val_recall_6: 0.7222 - val_true_negatives_6: 266.0000 - val_true_positives_6: 117.0000
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7840 - auc_6: 0.8423 - false_negatives_6: 137.2500 - false_positives_6: 55.3571 - loss: 0.4713 - precision_6: 0.7884 - recall_6: 0.6064 - true_negatives_6: 513.6786 - true_positives_6: 216.7143 - val_accuracy: 0.7996 - val_auc_6: 0.8404 - val_false_negatives_6: 62.0000 - val_false_positives_6: 35.0000 - val_loss: 0.4623 - val_precision_6: 0.7407 - val_recall_6: 0.6173 - val_true_negatives_6: 287.0000 - val_true_positives_6: 100.0000
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7817 - auc_6: 0.8398 - false_negatives_6: 134.1429 - false_positives_6: 63.1429 - loss: 0.4734 - precision_6: 0.7889 - recall_6: 0.5988 - true_negatives_6: 504.8214 - true_positives_6: 220.8929 - val_accuracy: 0.8037 - val_auc_6: 0.8398 - val_false_negatives_6: 59.0000 - val_false_positives_6: 36.0000 - val_loss: 0.4698 - val_precision_6: 0.7410 - val_recall_6: 0.6358 - val_true_negatives_6: 286.0000 - val_true_positives_6: 103.0000
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7821 - auc_6: 0.8223 - false_negatives_6: 146.4286 - false_positives_6: 51.6071 - loss: 0.4979 - precision_6: 0.8111 - recall_6: 0.5776 - true_negatives_6: 515.5000 - true_positives_6: 209.4643 - val_accuracy: 0.7955 - val_auc_6: 0.8341 - val_false_negatives_6: 57.0000 - val_false_positives_6: 42.0000 - val_loss: 0.4729 - val_precision_6: 0.7143 - val_recall_6: 0.6481 - val_true_negatives_6: 280.0000 - val_true_positives_6: 105.0000
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7853 - auc_6: 0.8371 - false_negatives_6: 143.1071 - false_positives_6: 53.9643 - loss: 0.4694 - precision_6: 0.8071 - recall_6: 0.5886 - true_negatives_6: 513.8571 - true_positives_6: 212.0714 - val_accuracy: 0.7955 - val_auc_6: 0.8386 - val_false_negatives_6: 45.0000 - val_false_positives_6: 54.0000 - val_loss: 0.4905 - val_precision_6: 0.6842 - val_recall_6: 0.7222 - val_true_negatives_6: 268.0000 - val_true_positives_6: 117.0000
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7893 - auc_6: 0.8401 - false_negatives_6: 137.3571 - false_positives_6: 54.8571 - loss: 0.4714 - precision_6: 0.7994 - recall_6: 0.6133 - true_negatives_6: 512.3214 - true_positives_6: 218.4643 - val_accuracy: 0.7975 - val_auc_6: 0.8322 - val_false_negatives_6: 47.0000 - val_false_positives_6: 51.0000 - val_loss: 0.4895 - val_precision_6: 0.6928 - val_recall_6: 0.7099 - val_true_negatives_6: 271.0000 - val_true_positives_6: 115.0000
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7887 - auc_6: 0.8394 - false_negatives_6: 124.7500 - false_positives_6: 64.4643 - loss: 0.4719 - precision_6: 0.7753 - recall_6: 0.6356 - true_negatives_6: 505.8214 - true_positives_6: 227.9643 - val_accuracy: 0.8037 - val_auc_6: 0.8380 - val_false_negatives_6: 47.0000 - val_false_positives_6: 48.0000 - val_loss: 0.4841 - val_precision_6: 0.7055 - val_recall_6: 0.7099 - val_true_negatives_6: 274.0000 - val_true_positives_6: 115.0000
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7850 - auc_6: 0.8452 - false_negatives_6: 134.7143 - false_positives_6: 59.0714 - loss: 0.4660 - precision_6: 0.7848 - recall_6: 0.6119 - true_negatives_6: 509.4286 - true_positives_6: 219.7857 - val_accuracy: 0.7955 - val_auc_6: 0.8360 - val_false_negatives_6: 55.0000 - val_false_positives_6: 44.0000 - val_loss: 0.4804 - val_precision_6: 0.7086 - val_recall_6: 0.6605 - val_true_negatives_6: 278.0000 - val_true_positives_6: 107.0000
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7906 - auc_6: 0.8386 - false_negatives_6: 128.8571 - false_positives_6: 61.6071 - loss: 0.4711 - precision_6: 0.7873 - recall_6: 0.6291 - true_negatives_6: 505.9286 - true_positives_6: 226.6071 - val_accuracy: 0.8037 - val_auc_6: 0.8379 - val_false_negatives_6: 57.0000 - val_false_positives_6: 38.0000 - val_loss: 0.4725 - val_precision_6: 0.7343 - val_recall_6: 0.6481 - val_true_negatives_6: 284.0000 - val_true_positives_6: 105.0000
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7783 - auc_6: 0.8316 - false_negatives_6: 141.1071 - false_positives_6: 54.6071 - loss: 0.4900 - precision_6: 0.8013 - recall_6: 0.5814 - true_negatives_6: 511.6786 - true_positives_6: 215.6071 - val_accuracy: 0.7955 - val_auc_6: 0.8359 - val_false_negatives_6: 49.0000 - val_false_positives_6: 50.0000 - val_loss: 0.4909 - val_precision_6: 0.6933 - val_recall_6: 0.6975 - val_true_negatives_6: 272.0000 - val_true_positives_6: 113.0000
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7813 - auc_6: 0.8288 - false_negatives_6: 135.2857 - false_positives_6: 61.2857 - loss: 0.4864 - precision_6: 0.7822 - recall_6: 0.6080 - true_negatives_6: 506.1429 - true_positives_6: 220.2857 - val_accuracy: 0.8058 - val_auc_6: 0.8383 - val_false_negatives_6: 46.0000 - val_false_positives_6: 48.0000 - val_loss: 0.4845 - val_precision_6: 0.7073 - val_recall_6: 0.7160 - val_true_negatives_6: 274.0000 - val_true_positives_6: 116.0000
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7885 - auc_6: 0.8334 - false_negatives_6: 135.8214 - false_positives_6: 57.8929 - loss: 0.4800 - precision_6: 0.7905 - recall_6: 0.6232 - true_negatives_6: 508.3929 - true_positives_6: 220.8929 - val_accuracy: 0.7851 - val_auc_6: 0.8363 - val_false_negatives_6: 48.0000 - val_false_positives_6: 56.0000 - val_loss: 0.4762 - val_precision_6: 0.6706 - val_recall_6: 0.7037 - val_true_negatives_6: 266.0000 - val_true_positives_6: 114.0000
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7852 - auc_6: 0.8243 - false_negatives_6: 135.6071 - false_positives_6: 58.3929 - loss: 0.4843 - precision_6: 0.7858 - recall_6: 0.6118 - true_negatives_6: 508.7857 - true_positives_6: 220.2143 - val_accuracy: 0.8099 - val_auc_6: 0.8387 - val_false_negatives_6: 52.0000 - val_false_positives_6: 40.0000 - val_loss: 0.4726 - val_precision_6: 0.7333 - val_recall_6: 0.6790 - val_true_negatives_6: 282.0000 - val_true_positives_6: 110.0000
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7854 - auc_6: 0.8328 - false_negatives_6: 145.9286 - false_positives_6: 44.8571 - loss: 0.4842 - precision_6: 0.8250 - recall_6: 0.5786 - true_negatives_6: 521.5714 - true_positives_6: 210.6429 - val_accuracy: 0.8058 - val_auc_6: 0.8372 - val_false_negatives_6: 48.0000 - val_false_positives_6: 46.0000 - val_loss: 0.4758 - val_precision_6: 0.7125 - val_recall_6: 0.7037 - val_true_negatives_6: 276.0000 - val_true_positives_6: 114.0000
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7903 - auc_6: 0.8434 - false_negatives_6: 121.4643 - false_positives_6: 69.5000 - loss: 0.4672 - precision_6: 0.7739 - recall_6: 0.6502 - true_negatives_6: 497.5714 - true_positives_6: 234.4643 - val_accuracy: 0.7975 - val_auc_6: 0.8374 - val_false_negatives_6: 49.0000 - val_false_positives_6: 49.0000 - val_loss: 0.4807 - val_precision_6: 0.6975 - val_recall_6: 0.6975 - val_true_negatives_6: 273.0000 - val_true_positives_6: 113.0000
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7880 - auc_6: 0.8432 - false_negatives_6: 136.9286 - false_positives_6: 55.3214 - loss: 0.4693 - precision_6: 0.8032 - recall_6: 0.6039 - true_negatives_6: 512.6786 - true_positives_6: 218.0714 - val_accuracy: 0.8058 - val_auc_6: 0.8362 - val_false_negatives_6: 51.0000 - val_false_positives_6: 43.0000 - val_loss: 0.4756 - val_precision_6: 0.7208 - val_recall_6: 0.6852 - val_true_negatives_6: 279.0000 - val_true_positives_6: 111.0000
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7934 - auc_6: 0.8459 - false_negatives_6: 125.3214 - false_positives_6: 63.8571 - loss: 0.4637 - precision_6: 0.7840 - recall_6: 0.6406 - true_negatives_6: 505.0000 - true_positives_6: 228.8214 - val_accuracy: 0.7996 - val_auc_6: 0.8353 - val_false_negatives_6: 48.0000 - val_false_positives_6: 49.0000 - val_loss: 0.4914 - val_precision_6: 0.6994 - val_recall_6: 0.7037 - val_true_negatives_6: 273.0000 - val_true_positives_6: 114.0000
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7924 - auc_6: 0.8502 - false_negatives_6: 124.1071 - false_positives_6: 65.7857 - loss: 0.4553 - precision_6: 0.7795 - recall_6: 0.6427 - true_negatives_6: 503.4643 - true_positives_6: 229.6429 - val_accuracy: 0.8037 - val_auc_6: 0.8423 - val_false_negatives_6: 64.0000 - val_false_positives_6: 31.0000 - val_loss: 0.4538 - val_precision_6: 0.7597 - val_recall_6: 0.6049 - val_true_negatives_6: 291.0000 - val_true_positives_6: 98.0000
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7854 - auc_6: 0.8451 - false_negatives_6: 131.7143 - false_positives_6: 61.5000 - loss: 0.4695 - precision_6: 0.7990 - recall_6: 0.6018 - true_negatives_6: 507.3214 - true_positives_6: 222.4643 - val_accuracy: 0.7893 - val_auc_6: 0.8238 - val_false_negatives_6: 45.0000 - val_false_positives_6: 57.0000 - val_loss: 0.5061 - val_precision_6: 0.6724 - val_recall_6: 0.7222 - val_true_negatives_6: 265.0000 - val_true_positives_6: 117.0000
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8013 - auc_6: 0.8430 - false_negatives_6: 117.1786 - false_positives_6: 64.8571 - loss: 0.4648 - precision_6: 0.7853 - recall_6: 0.6703 - true_negatives_6: 503.2143 - true_positives_6: 237.7500 - val_accuracy: 0.8017 - val_auc_6: 0.8312 - val_false_negatives_6: 49.0000 - val_false_positives_6: 47.0000 - val_loss: 0.4858 - val_precision_6: 0.7063 - val_recall_6: 0.6975 - val_true_negatives_6: 275.0000 - val_true_positives_6: 113.0000
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7859 - auc_6: 0.8363 - false_negatives_6: 134.8214 - false_positives_6: 60.6786 - loss: 0.4786 - precision_6: 0.7869 - recall_6: 0.6185 - true_negatives_6: 506.8929 - true_positives_6: 220.6071 - val_accuracy: 0.8079 - val_auc_6: 0.8383 - val_false_negatives_6: 55.0000 - val_false_positives_6: 38.0000 - val_loss: 0.4653 - val_precision_6: 0.7379 - val_recall_6: 0.6605 - val_true_negatives_6: 284.0000 - val_true_positives_6: 107.0000
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7894 - auc_6: 0.8485 - false_negatives_6: 126.3929 - false_positives_6: 66.3571 - loss: 0.4604 - precision_6: 0.7849 - recall_6: 0.6315 - true_negatives_6: 501.8929 - true_positives_6: 228.3571 - val_accuracy: 0.7748 - val_auc_6: 0.8241 - val_false_negatives_6: 58.0000 - val_false_positives_6: 51.0000 - val_loss: 0.4902 - val_precision_6: 0.6710 - val_recall_6: 0.6420 - val_true_negatives_6: 271.0000 - val_true_positives_6: 104.0000
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7857 - auc_6: 0.8395 - false_negatives_6: 132.3214 - false_positives_6: 60.9643 - loss: 0.4799 - precision_6: 0.7899 - recall_6: 0.6097 - true_negatives_6: 506.3929 - true_positives_6: 223.3214 - val_accuracy: 0.7851 - val_auc_6: 0.8233 - val_false_negatives_6: 47.0000 - val_false_positives_6: 57.0000 - val_loss: 0.5065 - val_precision_6: 0.6686 - val_recall_6: 0.7099 - val_true_negatives_6: 265.0000 - val_true_positives_6: 115.0000
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7864 - auc_6: 0.8380 - false_negatives_6: 128.9643 - false_positives_6: 62.3571 - loss: 0.4745 - precision_6: 0.7852 - recall_6: 0.6162 - true_negatives_6: 505.8214 - true_positives_6: 225.8571 - val_accuracy: 0.8120 - val_auc_6: 0.8434 - val_false_negatives_6: 55.0000 - val_false_positives_6: 36.0000 - val_loss: 0.4674 - val_precision_6: 0.7483 - val_recall_6: 0.6605 - val_true_negatives_6: 286.0000 - val_true_positives_6: 107.0000
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7867 - auc_6: 0.8424 - false_negatives_6: 136.1786 - false_positives_6: 57.9286 - loss: 0.4634 - precision_6: 0.8001 - recall_6: 0.5911 - true_negatives_6: 512.2143 - true_positives_6: 216.6786 - val_accuracy: 0.8037 - val_auc_6: 0.8326 - val_false_negatives_6: 57.0000 - val_false_positives_6: 38.0000 - val_loss: 0.4858 - val_precision_6: 0.7343 - val_recall_6: 0.6481 - val_true_negatives_6: 284.0000 - val_true_positives_6: 105.0000
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7885 - auc_6: 0.8416 - false_negatives_6: 137.7143 - false_positives_6: 56.3571 - loss: 0.4755 - precision_6: 0.8126 - recall_6: 0.5995 - true_negatives_6: 511.3929 - true_positives_6: 217.5357 - val_accuracy: 0.7872 - val_auc_6: 0.8254 - val_false_negatives_6: 49.0000 - val_false_positives_6: 54.0000 - val_loss: 0.4993 - val_precision_6: 0.6766 - val_recall_6: 0.6975 - val_true_negatives_6: 268.0000 - val_true_positives_6: 113.0000
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8016 - auc_6: 0.8536 - false_negatives_6: 126.5357 - false_positives_6: 57.7143 - loss: 0.4534 - precision_6: 0.8050 - recall_6: 0.6500 - true_negatives_6: 509.0357 - true_positives_6: 229.7143 - val_accuracy: 0.7831 - val_auc_6: 0.8252 - val_false_negatives_6: 49.0000 - val_false_positives_6: 56.0000 - val_loss: 0.5147 - val_precision_6: 0.6686 - val_recall_6: 0.6975 - val_true_negatives_6: 266.0000 - val_true_positives_6: 113.0000
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7909 - auc_6: 0.8345 - false_negatives_6: 137.1071 - false_positives_6: 51.3929 - loss: 0.4811 - precision_6: 0.8202 - recall_6: 0.6035 - true_negatives_6: 514.6071 - true_positives_6: 219.8929 - val_accuracy: 0.7748 - val_auc_6: 0.8206 - val_false_negatives_6: 41.0000 - val_false_positives_6: 68.0000 - val_loss: 0.5284 - val_precision_6: 0.6402 - val_recall_6: 0.7469 - val_true_negatives_6: 254.0000 - val_true_positives_6: 121.0000
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7932 - auc_6: 0.8399 - false_negatives_6: 114.0714 - false_positives_6: 71.0357 - loss: 0.4736 - precision_6: 0.7665 - recall_6: 0.6772 - true_negatives_6: 496.4643 - true_positives_6: 241.4286 - val_accuracy: 0.7707 - val_auc_6: 0.8131 - val_false_negatives_6: 52.0000 - val_false_positives_6: 59.0000 - val_loss: 0.5227 - val_precision_6: 0.6509 - val_recall_6: 0.6790 - val_true_negatives_6: 263.0000 - val_true_positives_6: 110.0000
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8024 - auc_6: 0.8446 - false_negatives_6: 120.3214 - false_positives_6: 61.7500 - loss: 0.4706 - precision_6: 0.7937 - recall_6: 0.6639 - true_negatives_6: 505.3571 - true_positives_6: 235.5714 - val_accuracy: 0.7893 - val_auc_6: 0.8289 - val_false_negatives_6: 41.0000 - val_false_positives_6: 61.0000 - val_loss: 0.4975 - val_precision_6: 0.6648 - val_recall_6: 0.7469 - val_true_negatives_6: 261.0000 - val_true_positives_6: 121.0000
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7919 - auc_6: 0.8412 - false_negatives_6: 118.4286 - false_positives_6: 67.7143 - loss: 0.4708 - precision_6: 0.7738 - recall_6: 0.6636 - true_negatives_6: 498.5000 - true_positives_6: 238.3571 - val_accuracy: 0.7893 - val_auc_6: 0.8288 - val_false_negatives_6: 48.0000 - val_false_positives_6: 54.0000 - val_loss: 0.4985 - val_precision_6: 0.6786 - val_recall_6: 0.7037 - val_true_negatives_6: 268.0000 - val_true_positives_6: 114.0000
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7899 - auc_6: 0.8501 - false_negatives_6: 120.7500 - false_positives_6: 66.8214 - loss: 0.4580 - precision_6: 0.7768 - recall_6: 0.6470 - true_negatives_6: 501.5000 - true_positives_6: 233.9286 - val_accuracy: 0.7893 - val_auc_6: 0.8241 - val_false_negatives_6: 42.0000 - val_false_positives_6: 60.0000 - val_loss: 0.5079 - val_precision_6: 0.6667 - val_recall_6: 0.7407 - val_true_negatives_6: 262.0000 - val_true_positives_6: 120.0000
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8026 - auc_6: 0.8559 - false_negatives_6: 114.1429 - false_positives_6: 66.6071 - loss: 0.4537 - precision_6: 0.7826 - recall_6: 0.6772 - true_negatives_6: 500.3571 - true_positives_6: 241.8929 - val_accuracy: 0.7810 - val_auc_6: 0.8118 - val_false_negatives_6: 53.0000 - val_false_positives_6: 53.0000 - val_loss: 0.5214 - val_precision_6: 0.6728 - val_recall_6: 0.6728 - val_true_negatives_6: 269.0000 - val_true_positives_6: 109.0000
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7981 - auc_6: 0.8496 - false_negatives_6: 126.3929 - false_positives_6: 60.7857 - loss: 0.4647 - precision_6: 0.7960 - recall_6: 0.6378 - true_negatives_6: 507.9286 - true_positives_6: 227.8929 - val_accuracy: 0.7934 - val_auc_6: 0.8259 - val_false_negatives_6: 51.0000 - val_false_positives_6: 49.0000 - val_loss: 0.4923 - val_precision_6: 0.6938 - val_recall_6: 0.6852 - val_true_negatives_6: 273.0000 - val_true_positives_6: 111.0000
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7977 - auc_6: 0.8606 - false_negatives_6: 121.6429 - false_positives_6: 59.5000 - loss: 0.4468 - precision_6: 0.8017 - recall_6: 0.6440 - true_negatives_6: 506.6429 - true_positives_6: 235.2143 - val_accuracy: 0.7851 - val_auc_6: 0.8196 - val_false_negatives_6: 46.0000 - val_false_positives_6: 58.0000 - val_loss: 0.5051 - val_precision_6: 0.6667 - val_recall_6: 0.7160 - val_true_negatives_6: 264.0000 - val_true_positives_6: 116.0000
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7960 - auc_6: 0.8463 - false_negatives_6: 129.4286 - false_positives_6: 55.9286 - loss: 0.4600 - precision_6: 0.7973 - recall_6: 0.6333 - true_negatives_6: 511.7500 - true_positives_6: 225.8929 - val_accuracy: 0.7769 - val_auc_6: 0.8197 - val_false_negatives_6: 49.0000 - val_false_positives_6: 59.0000 - val_loss: 0.5039 - val_precision_6: 0.6570 - val_recall_6: 0.6975 - val_true_negatives_6: 263.0000 - val_true_positives_6: 113.0000
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8050 - auc_6: 0.8500 - false_negatives_6: 128.0357 - false_positives_6: 51.3571 - loss: 0.4575 - precision_6: 0.8179 - recall_6: 0.6379 - true_negatives_6: 515.9643 - true_positives_6: 227.6429 - val_accuracy: 0.7934 - val_auc_6: 0.8271 - val_false_negatives_6: 44.0000 - val_false_positives_6: 56.0000 - val_loss: 0.4985 - val_precision_6: 0.6782 - val_recall_6: 0.7284 - val_true_negatives_6: 266.0000 - val_true_positives_6: 118.0000
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7986 - auc_6: 0.8491 - false_negatives_6: 127.8214 - false_positives_6: 55.8214 - loss: 0.4596 - precision_6: 0.8002 - recall_6: 0.6329 - true_negatives_6: 512.4286 - true_positives_6: 226.9286 - val_accuracy: 0.7934 - val_auc_6: 0.8215 - val_false_negatives_6: 45.0000 - val_false_positives_6: 55.0000 - val_loss: 0.5157 - val_precision_6: 0.6802 - val_recall_6: 0.7222 - val_true_negatives_6: 267.0000 - val_true_positives_6: 117.0000
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8122 - auc_6: 0.8568 - false_negatives_6: 122.2857 - false_positives_6: 51.3571 - loss: 0.4514 - precision_6: 0.8255 - recall_6: 0.6572 - true_negatives_6: 516.0000 - true_positives_6: 233.3571 - val_accuracy: 0.7789 - val_auc_6: 0.8163 - val_false_negatives_6: 46.0000 - val_false_positives_6: 61.0000 - val_loss: 0.5136 - val_precision_6: 0.6554 - val_recall_6: 0.7160 - val_true_negatives_6: 261.0000 - val_true_positives_6: 116.0000

# %%
# eval_metrices = ann.evaluate(test_dataset)
plot_metrices(ann_hist, names = ['loss', 'val_loss', 'accuracy', 'val_accuracy', 'auc_6', 'val_auc_6'])

# %%
y_pred = ann.predict(test_dataset)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
    
    # Compute AUC
roc_auc = auc(fpr, tpr)

    # Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')  # Diagonal line for random guess
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title('ANN ROC Curve')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()
